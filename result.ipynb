# %% [markdown]
# ### top

# %% [markdown]
# ![参数.png](data:image/png;base64,...)

# %% [markdown]
# ###  TransE

# %% [markdown]
# #### GADM9 参数：lr=0.0001 margin=1.5 dim=100

# %% [markdown]
# ##### Adam

# %%
# !python3 GADM9_TransE.py  # 421
# Out:
# Loading data...
# Train set: 40799 entities, 9 relations, 422154 triplets.
# Valid set: 52769 triplets, Test set: 52773 triplets.
# Loading model...
# TransEModel(
#   (ent_emb): Embedding(40799, 100)
#   (rel_emb): Embedding(9, 100)
# )
# lr: 0.0001, margin: 1.5, dim 100, total epoch: 20000, device: cuda:0, batch size: 5120, optim: Adam
# Training...
# Epoch [ 205/20000] | mean loss:  500.210, time: 0:05:00, Val Hit@10: 18.89% *
# Epoch [ 369/20000] | mean loss:  115.802, time: 0:12:20, Val Hit@10: 55.57% *
# Epoch [ 525/20000] | mean loss:   51.038, time: 0:18:53, Val Hit@10: 67.63% *
# Epoch [ 703/20000] | mean loss:   31.513, time: 0:26:09, Val Hit@10: 70.38% *
# Epoch [ 863/20000] | mean loss:   24.643, time: 0:33:08, Val Hit@10: 71.34% *
# Epoch [1024/20000] | mean loss:   22.772, time: 0:39:54, Val Hit@10: 71.76% *
# Epoch [1191/20000] | mean loss:   20.884, time: 0:46:54, Val Hit@10: 71.89% *
# Epoch [1368/20000] | mean loss:   19.880, time: 0:53:53, Val Hit@10: 71.86%
# ...

# %% [markdown]
# #### GeoDBpedia21 参数：lr=0.001 margin=10 dim=100

# %% [markdown]
# ###### Adam

# %%
# !python3 GeoDBpedia21_TransE.py
# Out:
# Loading data...
# Train set: 84988 entities, 21 relations, 91217 triplets.
# Valid set: 3973 triplets, Test set: 3982 triplets.
# Loading model...
# loading ckpt sucessful, start on epoch 1001...
# TransEModel(
#   (ent_emb): Embedding(84988, 100)
#   (rel_emb): Embedding(21, 100)
# )
# lr: 0.001, margin: 10, dim 100, total epoch: 20000, device: cuda:0, batch size: 5120, optim: Adam
# Training...
# Epoch [2000/20000] | mean loss: 2226.729, time: 0:01:38
# Train loss: 2226.729, Val Hit@10: 6.38%, Time 0:01:42 *
# Epoch [3000/20000] | mean loss: 2232.646, time: 0:03:20
# Train loss: 2232.646, Val Hit@10: 7.63%, Time 0:03:23 *
# Epoch [4000/20000] | mean loss: 2125.797, time: 0:05:02
# Train loss: 2125.797, Val Hit@10: 9.82%, Time 0:05:05 *
# Epoch [5000/20000] | mean loss: 2063.019, time: 0:06:43
# Train loss: 2063.019, Val Hit@10: 8.66%, Time 0:06:46
# Epoch [6000/20000] | mean loss: 2074.975, time: 0:08:24
# Train loss: 2074.975, Val Hit@10: 10.31%, Time 0:08:27 *
# ...

# %% [markdown]
# ##### SGD

# %%
# !python3 GeoDBpedia21_TransE.py
# Out:
# Loading data...
# Train set: 84988 entities, 21 relations, 91217 triplets.
# Valid set: 3973 triplets, Test set: 3982 triplets.
# Loading model...
# TransEModel(
#   (ent_emb): Embedding(84988, 100)
#   (rel_emb): Embedding(21, 100)
# )
# lr: 0.001, margin: 10, dim 100, total epoch: 20000, device: cuda:0, batch size: 5120, optim: SGD
# Training...
# Epoch [ 500/20000] | mean loss: 2338.208, time: 0:00:58
# Train loss: 2338.208, Val Hit@10: 8.75%, Time 0:01:05 *
# Epoch [1000/20000] | mean loss: 2189.619, time: 0:02:03
# Train loss: 2189.619, Val Hit@10: 7.29%, Time 0:02:09
# Epoch [1500/20000] | mean loss: 2104.714, time: 0:03:07
# Train loss: 2104.714, Val Hit@10: 8.14%, Time 0:03:14
# Epoch [2000/20000] | mean loss: 2110.780, time: 0:04:12
# Train loss: 2110.780, Val Hit@10: 6.95%, Time 0:04:18
# Epoch [2500/20000] | mean loss: 2113.251, time: 0:05:17
# Train loss: 2113.251, Val Hit@10: 8.57%, Time 0:05:23
# Epoch [3000/20000] | mean loss: 2060.377, time: 0:06:22
# ...

# %% [markdown]
# ### TransR

# %% [markdown]
# #### GADM9  参数：lr=0.0001 margin=1 dim=100

# %%
# !python3 GADM9_TransR.py  # 421
# Out:
# Loading data...
# Train set: 40799 entities, 9 relations, 422154 triplets.
# Valid set: 52769 triplets, Test set: 52773 triplets.
# Loading model...
# loading ckpt sucessful, start on epoch 11088...
# TransRModel(
#   (ent_emb): Embedding(40799, 100)
#   (rel_emb): Embedding(9, 100)
#   (proj_mat): Embedding(9, 10000)
# )
# lr: 0.0001, margin: 1, dim 100, total epoch: 20000, device: cuda:0, batch size: 512, optim: Adam
# Training...
# Epoch [11163/20000] | mean loss:    0.167, time: 0:08:03, Val Hit@10: 76.47% *
# ...

# %% [markdown]
# #### GeoDBpedia21 参数：lr=0.001 margin=1 dim=100

# %%
# !python3 GeoDBpedia21_TransR.py
# Out:
# Loading data...
# Train set: 84988 entities, 21 relations, 91217 triplets.
# Valid set: 3973 triplets, Test set: 3982 triplets.
# Loading model...
# loading ckpt sucessful, start on epoch 3001...
# TransRModel(
#   (ent_emb): Embedding(84988, 100)
#   (rel_emb): Embedding(21, 100)
#   (proj_mat): Embedding(21, 10000)
# )
# lr: 0.001, margin: 1, dim 100, total epoch: 20000, device: cuda:0, batch size: 5120, optim: Adam
# Training...
# Epoch [4000/20000] | mean loss:    3.730, time: 0:03:43
# Train loss:    3.730, Val Hit@10: 22.40%, Time 0:03:59
# ...

# %% [markdown]
# ### TransD

# %% [markdown]
# #### GADM9  参数：lr=0.0001 margin=0.5 dim=100

# %%
# !python3 GADM9_TransD.py  #421
# Out:
# Loading data...
# Train set: 40799 entities, 9 relations, 422154 triplets.
# Valid set: 52769 triplets, Test set: 52773 triplets.
# Loading model...
# loading ckpt sucessful, start on epoch 22653...
# TransDModel(
#   (ent_emb): Embedding(40799, 100)
#   (rel_emb): Embedding(9, 100)
#   (ent_proj_vect): Embedding(40799, 100)
#   (rel_proj_vect): Embedding(9, 100)
# )
# lr: 0.0001, margin: 0.5, dim 100, total epoch: 50000, device: cuda:0, batch size: 5120, optim: Adam
# Training...
# Epoch [22727/50000] | mean loss:    0.497, time: 0:01:00, Val Hit@10: 80.70% *
# ...

# %% [markdown]
# #### GeoDBpedia21 参数：lr=0.001 margin=1 dim=100

# %%
# !python3 GeoDBpedia21_TransD.py
# Out:
# Loading data...
# Train set: 84988 entities, 21 relations, 91217 triplets.
# Valid set: 3973 triplets, Test set: 3982 triplets.
# Loading model...
# TransDModel(
#   (ent_emb): Embedding(84988, 100)
#   (rel_emb): Embedding(21, 100)
#   (ent_proj_vect): Embedding(84988, 100)
#   (rel_proj_vect): Embedding(21, 100)
# )
# lr: 0.001, margin: 1, dim 100, total epoch: 20000, device: cuda:0, batch size: 5120, optim: Adam
# Training...
# Epoch [ 300/20000] | mean loss:    7.411, time: 0:01:00
# Train loss:    7.411, Val Hit@10: 37.38%, Time 0:01:15 *
# ...

# %%
# !python3 run_test.py
# Out:
# Loading data...
# Train set: 84988 entities, 21 relations, 91217 triplets.
# Valid set: 3973 triplets, Test set: 3982 triplets.
# loading ckpt successful, start evaluate on test data...
# TransDModel(
#   (ent_emb): Embedding(84988, 100)
#   (rel_emb): Embedding(21, 100)
#   (ent_proj_vect): Embedding(84988, 100)
#   (rel_proj_vect): Embedding(21, 100)
# )
# Link prediction evaluation: 100%|████████████| 16/16 [00:12<00:00,  1.30batch/s]
# Entity prediction:
# Hit@10 : 39.10% 		 Filt. Hit@10 : 46.89%
# Mean Rank : 5341.95 	 Filt. Mean Rank : 5227.58
# Relation prediction evaluation: 100%|████████| 16/16 [00:00<00:00, 73.68batch/s]
# Relation prediction:
# Hit@1 : 73.03% 		 Filt. Hit@1 : 82.62%
# Mean Rank : 2.12 	 Filt. Mean Rank : 1.99

# %% [markdown]
# ### TransE_GDR

# %% [markdown]
# #### GADM9  参数：lr=0.0001 margin=0.5 dim=100

# %%
# !python3 GADM9_TransE_GDR.py  # 421
# Out:
# Loading data...
# Train set: 40799 entities, 9 relations, 422154 triplets.
# Valid set: 52769 triplets, Test set: 52773 triplets.
# Loading model...
# loading ckpt sucessful, start on epoch 190...
# TransE_GDRModel(
#   (ent_emb): Embedding(40799, 100)
#   (rel_emb): Embedding(9, 100)
# )
# lr: 0.0001, margin: 0.5, dim 100, total epoch: 20000, device: cuda:0, batch size: 2048, optim: Adam
# Training...
# Epoch [  213/20000] | mean loss:    5.362, time: 0:10:10, Val Hit@10: 84.92% *
# Epoch [  236/20000] | mean loss:    4.931, time: 0:22:46, Val Hit@10: 84.74%
# Epoch [  259/20000] | mean loss:    4.710, time: 0:35:12, Val Hit@10: 84.59%
# Epoch [  282/20000] | mean loss:    4.482, time: 0:47:30, Val Hit@10: 84.33%
# Epoch [  305/20000] | mean loss:    4.301, time: 0:59:15, Val Hit@10: 84.13%
# Epoch [  308/20000] | mean loss:    4.298, time: 1:02:42
# No optimization for a long time, auto-stopping...
#
# Training done, start evaluate on test data...
# ...

# %% [markdown]
# #### GeoDBpedia21 参数：lr=0.001 margin=1.5 dim=100

# %%
# !python3 GeoDBpedia21_TransE_GDR.py  #!
# Out:
# Loading data...
# Train set: 84988 entities, 21 relations, 91217 triplets.
# Valid set: 3973 triplets, Test set: 3982 triplets.
# Loading model...
# TransE_GDRModel(
#   (ent_emb): Embedding(84988, 100)
#   (rel_emb): Embedding(21, 100)
# )
# lr: 0.001, margin: 10, dim 100, total epoch: 20000, device: cuda:0, batch size: 5120, optim: Adam
# Training...
# Epoch [   68/20000] | mean loss: 45611.358, time: 0:05:04, Val Hit@10: 48.26% *
# Epoch [  137/20000] | mean loss: 43447.492, time: 0:10:13, Val Hit@10: 39.93%
# Epoch [  204/20000] | mean loss: 43144.948, time: 0:15:21, Val Hit@10: 30.13%
# Epoch [  271/20000] | mean loss: 43025.558, time: 0:20:28, Val Hit@10: 22.77%
# Epoch [  338/20000] | mean loss: 43022.218, time: 0:25:35, Val Hit@10: 17.03%
# Epoch [  401/20000] | mean loss: 43014.434, time: 0:30:12
# No optimization for a long time, auto-stopping...
#
# Training done, start evaluate on test data...
# Entity prediction:
# Hit@10 : 43.72% 		 Filt. Hit@10 : 47.90%
# ...

# %% [markdown]
# ### TransR_GDR

# %% [markdown]
# #### GADM9  参数：lr=0.0001 margin=1.5 dim=100

# %%
# !python3 GADM9_TransR_GDR.py  # 421
# Out:
# Loading data...
# Train set: 40799 entities, 9 relations, 422154 triplets.
# Valid set: 52769 triplets, Test set: 52773 triplets.
# Loading model...
# loading ckpt sucessful, start on epoch 1618...
# TransR_GDRModel(
#   (ent_emb): Embedding(40799, 100)
#   (rel_emb): Embedding(9, 100)
#   (proj_mat): Embedding(9, 10000)
# )
# lr: 0.0001, margin: 1.5, dim 100, total epoch: 20000, device: cuda:0, batch size: 512, optim: Adam
# Training...
# Epoch [1635/20000] | mean loss:    2.250, time: 0:08:10, Val Hit@10: 47.02% *
# ...

# %% [markdown]
# #### GeoDBpedia21 参数：lr=0.001 margin=0.5 dim=100

# %%
# !python3 GeoDBpedia21_TransR_GDR.py  #!
# Out:
# Loading data...
# Train set: 84988 entities, 21 relations, 91217 triplets.
# Valid set: 3973 triplets, Test set: 3982 triplets.
# Loading model...
# loading ckpt sucessful, start on epoch 2358...
# TransR_GDRModel(
#   (ent_emb): Embedding(84988, 100)
#   (rel_emb): Embedding(21, 100)
#   (proj_mat): Embedding(21, 10000)
# )
# lr: 0.001, margin: 0.5, dim 100, total epoch: 20000, device: cuda:0, batch size: 512, optim: Adam
# Training...
# Epoch [2450/20000] | mean loss:    9.349, time: 0:08:04, Val Hit@10: 13.72% *
# ...

# %% [markdown]
# ### TransD_GDR

# %% [markdown]
# #### GADM9  参数：lr=0.00001 margin=1 dim=100

# %%
# !python3 GADM9_TransD_GDR.py  # 421
# Out:
# Loading data...
# Train set: 40799 entities, 9 relations, 422154 triplets.
# Valid set: 52769 triplets, Test set: 52773 triplets.
# Loading model...
# loading ckpt sucessful, start on epoch 1771...
# TransD_GDRModel(
#   (ent_emb): Embedding(40799, 100)
#   (rel_emb): Embedding(9, 100)
#   (ent_proj_vect): Embedding(40799, 100)
#   (rel_proj_vect): Embedding(9, 100)
# )
# lr: 1e-05, margin: 1, dim 100, total epoch: 20000, device: cuda:0, batch size: 5120, optim: Adam
# Training...
# Epoch [1784/20000] | mean loss:  885.671, time: 0:05:18, Val Hit@10: 73.08% *
# ...

# %% [markdown]
# #### GeoDBpedia21 参数：lr=0.001 margin=1 dim=100

# %%
# !python3 GeoDBpedia21_TransD_GDR.py  # !!
# Out:
# Loading data...
# Train set: 84988 entities, 21 relations, 91217 triplets.
# Valid set: 3973 triplets, Test set: 3982 triplets.
# Loading model...
# loading ckpt sucessful, start on epoch 347...
# TransD_GDRModel(
#   (ent_emb): Embedding(84988, 100)
#   (rel_emb): Embedding(21, 100)
#   (ent_proj_vect): Embedding(84988, 100)
#   (rel_proj_vect): Embedding(21, 100)
# )
# lr: 0.001, margin: 1, dim 100, total epoch: 20000, device: cuda:0, batch size: 5120, optim: Adam
# Training...
# Epoch [ 438/20000] | mean loss:  472.143, time: 0:08:02, Val Hit@10: 48.35%
# ...

# %% [markdown]
# ### add 46

# %%
# !python3 GADM9_TransR.py  # 421
# Out:
# Loading data...
# Train set: 40799 entities, 9 relations, 422154 triplets.
# Valid set: 52769 triplets, Test set: 52773 triplets.
# Loading model...
# loading ckpt sucessful, start on epoch 11088...
# TransRModel(
#   (ent_emb): Embedding(40799, 100)
#   (rel_emb): Embedding(9, 100)
#   (proj_mat): Embedding(9, 10000)
# )
# lr: 0.0001, margin: 1, dim 100, total epoch: 20000, device: cuda:0, batch size: 512, optim: Adam
# Training...
# Epoch [11163/20000] | mean loss:    0.167, time: 0:08:03, Val Hit@10: 76.47% *
# ...
